# %% [markdown]
# <a href="https://colab.research.google.com/github/Harsh152003/Reinforcement_Learning/blob/main/Exp_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import random
np.random.seed(1) #function to select random values
#1000 random integers between 0 and 50
x = np.random.randint(0,50,1000) #100 values between 0 to 50
x
# Out:
# array([37, 43, 12,  8,  9, 11,  5, 15,  0, 16,  1, 12,  7, 45,  6, 25, 20,
#        37, 18, 20, 11, 42, 28, 29, 14,  4, 23, 23, 41, 49, 30, 32, 22, 13,
#        41,  9,  7, 22,  1,  0, 17,  8, 24, 13, 47, 42,  8, 30,  7,  3,  6,
#        21, 49,  3,  4, 24, 49, 43, 12, 26, 16, 45, 41, 18, 15,  0,  4, 25,
#        47, 34, 23,  7, 26, 25, 40, 22,  9,  3, 39, 23, 36, 27, 37, 19, 38,
#         8, 32, 34, 10, 23, 15, 47, 23, 25,  7, 28, 10, 46, 32, 24, 23,  1,
#        49, 13,  3,  0, 13,  6, 21,  6,  2, 12, 27, 21, 11,  7, 13,  8, 11,
#        12, 43, 20, 30, 36, 39,  7, 45,  4, 48, 18, 32, 13, 10, 23, 17,  7,
#        24, 10, 28, 20, 32, 12,  1, 30, 41, 24, 18, 33,  2, 44, 28, 39, 34,
#        10, 32, 41, 18, 22,  6,  2,  7, 39, 48, 15,  5, 17, 42, 20, 48, 22,
#        37, 13, 49, 33, 20, 10, 32, 25, 21, 39, 32, 19, 25, 49, 14, 13, 20,
#        43,  6, 13, 15, 24,  9,  2,  7,  5, 36, 37, 21, 40, 13, 27, 49, 49,
# ...

# %%
#Positive correlation with some noise
y = x + np.random.normal(0,10,1000)
y
# Out:
# array([ 20.91943595,  50.63680457,  26.1899858 ,   4.2567297 ,
#          4.76682859,  -1.41868013,   0.13974066,  12.68595762,
#         -2.4644001 ,  23.67966704,  -5.26864647,  44.705657  ,
#          3.929594  ,  41.15251149,   6.15189145,  16.87380256,
#         12.12197948,  23.85785176,  19.98609381,  17.29294368,
#         13.81247183,  29.45979256,  29.23125049,  15.30400214,
#          7.32581754,   8.57716492,   8.37879784,  25.63585484,
#         49.04095427,  58.34967036,  32.56479127,  29.70811918,
#          1.18361352,  25.66966811,  49.05104488,  18.60306431,
#         11.34949454,  28.80212162,  19.68884019,   1.50705284,
#         11.31341917,  20.74937886,  31.50733465,  21.09738523,
#         32.61895129,  58.59052608,  11.11072572,  32.15714494,
#          2.25252158,  -0.26341235,  -1.10116519,  10.9632299 ,
#         50.14247927,  13.13755659,  -3.20034693,  19.75343555,
#         57.20068833,  27.88677104,   7.24892855,   6.40492564,
# ...

# %%
np.corrcoef(x,y) #positive correlation
# Out:
# array([[1.        , 0.81543901],
#        [0.81543901, 1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x,y)
plt.show()

# %%
y = x - np.random.normal(0,10,1000)
y
np.corrcoef(x,y) #negative correlation
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x,y)
plt.show()

# %%
#Negative correlation
#1000 random integers between 0 and 50
x = np.random.randint(0,50,1000) #1000 values between 0 to 50
y = 100 - x +np.random.normal(0,5,1000)
np.corrcoef(x,y)
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x,y)
plt.show()

# %%
x = np.random.randint(0,50,1000)
y = np.random.randint(0,50,1000)
np.corrcoef(x,y) # 0 correlation
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x,y)
plt.show()

# %%
import pandas as pd
df = pd.DataFrame({'a': np.random.randint(0,50,1000)})
df['b'] = df['a'] + np.random.randint(0,10,1000) #+ve
df['c'] = 100- df['a'] + np.random.randint(0,5,1000) #-ve
df['d'] = np.random.randint(0,50,1000) #no corr

df.corr()

pd.plotting.scatter_matrix(df, figsize = (6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as  sns
import matplotlib.pyplot as plt
from scipy.stats import norm
df = pd.read_csv('House_Rent_Dataset.csv')
df.shape
df['Rent'].describe()
# Out:
# count    4.746000e+03
# mean     3.499345e+04
# std      7.810641e+04
# min      1.200000e+03
# 25%      1.000000e+04
# 50%      1.600000e+04
# 75%      3.300000e+04
# max      3.500000e+06
# Name: Rent, dtype: float64

# %%
plt.figure(figsize = (9,5))
df['Rent'].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.figure(figsize = (9,5))
df['BHK'].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize = (9,5))
df['Bathroom'].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize = (9,8))

sns.heatmap(corrmat, ax = ax, cmap = "YlGnBu", linewidths= 0.1)
# Out:
# <ipython-input-18-81ae2c0df2ac>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr()
# <Axes: >

# %%
corrmat = df.corr();
cg = sns.clustermap(corrmat, cmap="YlGnBu", linewidths= 0.1)
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(),rotation =0)
# Out:
# <ipython-input-19-ecc66ba25456>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr();
# [None, None, None, None, None, None, None, None]
